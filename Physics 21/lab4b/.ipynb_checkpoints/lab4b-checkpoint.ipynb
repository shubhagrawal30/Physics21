# %% [markdown]
# # Physics 21, Spring 2021
# # Shubh Agrawal, Class of 2022
# # Assignment 4b

# %%
import numpy as np
from matplotlib import pyplot as pl
import pymc3 as pm

# %% [markdown]
# # Part 1

# %% [markdown]
# We redo the coin tossing problem with $H_{true} = 3$

# %%
# 0 = heads, 1 = tails
def tossNCoins(H, n):
    return np.random.choice([1, 0], size = n, p = [H, 1-H])

H_true = 0.3
N = 512

data = tossNCoins(H_true, N)

# %%
def vary_number_of_chains_uniform_prior(num_chains = [1, 2, 4, 8]):
    iters = 1000
    pl.figure()
    for i, num_chain in enumerate(num_chains):
        with pm.Model() as model:
            # define uniform prior
            theta = pm.Uniform('theta', lower=0, upper=1)

            # define the likelihood
            likelihood = pm.Bernoulli('likelihood', theta, observed=data)

            # get the samples
            trace = pm.sample(iters, chains=num_chain)
            
            pl.hist(trace['theta'], bins = 100, density=True, histtype="step", label=num_chain)
            
    pl.title(r"uniform prior, varying number of chains with $n_{iters}=1000$")
    pl.xlabel(r"$\theta$")
    pl.ylabel("posterior density")
    pl.legend()

# %%
def vary_number_of_chains_gaussian_prior(num_chains = [1, 2, 4, 8]):
    iters = 1000
    pl.figure()
    for i, num_chain in enumerate(num_chains):
        with pm.Model() as model:
            # define uniform prior
            theta = pm.Normal('theta', mu=0.5, sigma=1)

            # define the likelihood
            likelihood = pm.Bernoulli('likelihood', theta, observed=data)

            # get the samples
            trace = pm.sample(iters, chains=num_chain)
            
            pl.hist(trace['theta'], bins = 100, density=True, histtype="step", label=num_chain)
            
    pl.title(r"gaussian prior, varying number of chains with $n_{iters}=1000$")
    pl.xlabel(r"$\theta$")
    pl.ylabel("posterior density")
    pl.legend()

# %%
# %matplotlib notebook
vary_number_of_chains_uniform_prior()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <ipython-input-59-c9713fdea7e6>:13: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(iters, chains=num_chain)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [theta]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 00:01<00:00 Sampling chain 0, 0 divergences]
#     </div>
# Sampling 1 chain for 1_000 tune and 1_000 draw iterations (1_000 + 1_000 draws total) took 1 seconds.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# <ipython-input-59-c9713fdea7e6>:13: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(iters, chains=num_chain)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [theta]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 00:02<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 1_000 draw iterations (2_000 + 2_000 draws total) took 8 seconds.
# <ipython-input-59-c9713fdea7e6>:13: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(iters, chains=num_chain)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 2 jobs)
# NUTS: [theta]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:08<00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 20 seconds.
# <ipython-input-59-c9713fdea7e6>:13: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(iters, chains=num_chain)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (8 chains in 2 jobs)
# NUTS: [theta]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='16000' class='' max='16000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [16000/16000 00:08<00:00 Sampling 8 chains, 0 divergences]
#     </div>
# Sampling 8 chains for 1_000 tune and 1_000 draw iterations (8_000 + 8_000 draws total) took 33 seconds.

# %%
# %matplotlib notebook
vary_number_of_chains_gaussian_prior()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <ipython-input-63-bac88eab64be>:13: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(iters, chains=num_chain)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [theta]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 00:00<00:00 Sampling chain 0, 0 divergences]
#     </div>
# Sampling 1 chain for 1_000 tune and 1_000 draw iterations (1_000 + 1_000 draws total) took 1 seconds.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# <ipython-input-63-bac88eab64be>:13: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(iters, chains=num_chain)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [theta]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 00:02<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 1_000 draw iterations (2_000 + 2_000 draws total) took 8 seconds.
# <ipython-input-63-bac88eab64be>:13: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(iters, chains=num_chain)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 2 jobs)
# NUTS: [theta]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:04<00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 14 seconds.
# <ipython-input-63-bac88eab64be>:13: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(iters, chains=num_chain)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (8 chains in 2 jobs)
# NUTS: [theta]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='16000' class='' max='16000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [16000/16000 00:12<00:00 Sampling 8 chains, 0 divergences]
#     </div>
# Sampling 8 chains for 1_000 tune and 1_000 draw iterations (8_000 + 8_000 draws total) took 35 seconds.

# %% [markdown]
# With either case increases the effective number of samples gives us a smoother curve."

# %%
def vary_number_of_iters_uniform_prior(num_iters = [1000, 2000, 4000, 8000]):
    num_chain = 2
    pl.figure()
    for i, iters in enumerate(num_iters):
        with pm.Model() as model:
            # define uniform prior
            theta = pm.Uniform('theta', lower=0, upper=1)

            # define the likelihood
            likelihood = pm.Bernoulli('likelihood', theta, observed=data)

            # get the samples
            trace = pm.sample(iters, chains=num_chain)
            
            pl.hist(trace['theta'], bins = 100, density=True, histtype="step", label=iters)
            
    pl.title(r"uniform prior, varying number of iterations with $n_{chains}=2$")
    pl.xlabel(r"$\theta$")
    pl.ylabel("posterior density")
    pl.legend()

# %%
def vary_number_of_iters_gaussian_prior(num_iters = [1000, 2000, 4000, 8000]):
    num_chain = 2
    pl.figure()
    for i, iters in enumerate(num_iters):
        with pm.Model() as model:
            # define uniform prior
            theta = pm.Normal('theta', mu=0.5, sigma=1)

            # define the likelihood
            likelihood = pm.Bernoulli('likelihood', theta, observed=data)

            # get the samples
            trace = pm.sample(iters, chains=num_chain)
            
            pl.hist(trace['theta'], bins = 100, density=True, histtype="step", label=iters)
            
    pl.title(r"gaussian prior, varying number of iterations with $n_{chains}=2$")
    pl.xlabel(r"$\theta$")
    pl.ylabel("posterior density")
    pl.legend()

# %%
# %matplotlib notebook
vary_number_of_iters_uniform_prior()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <ipython-input-68-b6c2e0366522>:13: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(iters, chains=num_chain)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [theta]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 00:02<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 1_000 draw iterations (2_000 + 2_000 draws total) took 8 seconds.
# <ipython-input-68-b6c2e0366522>:13: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(iters, chains=num_chain)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [theta]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='6000' class='' max='6000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [6000/6000 00:04<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 2_000 draw iterations (2_000 + 4_000 draws total) took 10 seconds.
# <ipython-input-68-b6c2e0366522>:13: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(iters, chains=num_chain)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [theta]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='10000' class='' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [10000/10000 00:05<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 4_000 draw iterations (2_000 + 8_000 draws total) took 10 seconds.
# <ipython-input-68-b6c2e0366522>:13: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(iters, chains=num_chain)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [theta]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='18000' class='' max='18000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [18000/18000 00:08<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 8_000 draw iterations (2_000 + 16_000 draws total) took 14 seconds.

# %%
# %matplotlib notebook
vary_number_of_iters_gaussian_prior()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <ipython-input-69-c0fe6399c088>:13: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(iters, chains=num_chain)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [theta]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 00:02<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 1_000 draw iterations (2_000 + 2_000 draws total) took 8 seconds.
# <ipython-input-69-c0fe6399c088>:13: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(iters, chains=num_chain)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [theta]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='6000' class='' max='6000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [6000/6000 00:05<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 2_000 draw iterations (2_000 + 4_000 draws total) took 11 seconds.
# <ipython-input-69-c0fe6399c088>:13: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(iters, chains=num_chain)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [theta]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='10000' class='' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [10000/10000 00:06<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 4_000 draw iterations (2_000 + 8_000 draws total) took 12 seconds.
# <ipython-input-69-c0fe6399c088>:13: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(iters, chains=num_chain)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [theta]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='18000' class='' max='18000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [18000/18000 00:14<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 8_000 draw iterations (2_000 + 16_000 draws total) took 20 seconds.

# %% [markdown]
# With either case increases the effective number of samples gives us a smoother curve.

# %%
def vary_mu(mus = [0.2, 0.4, 0.6, 0.8]):
    sigma = 0.1
    num_chain = 2
    iters = 5000
    pl.figure()
    for i, mu in enumerate(mus):
        with pm.Model() as model:
            # define uniform prior
            theta = pm.Normal('theta', mu=mu, sigma=sigma)

            # define the likelihood
            likelihood = pm.Bernoulli('likelihood', theta, observed=data)

            # get the samples
            trace = pm.sample(iters, chains=num_chain)
            
            pl.hist(trace['theta'], bins = 100, density=True, histtype="step", label=mu)
            
    pl.title(r"gaussian prior, $\sigma = 0.1$ varying $\mu$")
    pl.xlabel(r"$\theta$")
    pl.ylabel("posterior density")
    pl.legend()

# %%
def vary_sigma(sigmas = [0.05, 0.1, 0.2, 0.5]):
    mu = 0.2
    num_chain = 2
    iters = 5000
    pl.figure()
    for i, sigma in enumerate(sigmas):
        with pm.Model() as model:
            # define uniform prior
            theta = pm.Normal('theta', mu=mu, sigma=sigma)

            # define the likelihood
            likelihood = pm.Bernoulli('likelihood', theta, observed=data)

            # get the samples
            trace = pm.sample(iters, chains=num_chain)
            
            pl.hist(trace['theta'], bins = 100, density=True, histtype="step", label=sigma)
            
    pl.title(r"gaussian prior, $\mu = 0.5$ varying $\sigma$")
    pl.xlabel(r"$\theta$")
    pl.ylabel("posterior density")
    pl.legend()

# %%
# %matplotlib notebook
vary_mu()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <ipython-input-79-b13492fabd05>:15: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(iters, chains=num_chain)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [theta]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='12000' class='' max='12000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [12000/12000 00:10<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 5_000 draw iterations (2_000 + 10_000 draws total) took 16 seconds.
# <ipython-input-79-b13492fabd05>:15: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(iters, chains=num_chain)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [theta]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='12000' class='' max='12000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [12000/12000 00:08<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 5_000 draw iterations (2_000 + 10_000 draws total) took 13 seconds.
# The acceptance probability does not match the target. It is 0.8799827275249745, but should be close to 0.8. Try to increase the number of tuning steps.
# <ipython-input-79-b13492fabd05>:15: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(iters, chains=num_chain)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [theta]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='12000' class='' max='12000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [12000/12000 00:08<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 5_000 draw iterations (2_000 + 10_000 draws total) took 14 seconds.
# <ipython-input-79-b13492fabd05>:15: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(iters, chains=num_chain)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [theta]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='12000' class='' max='12000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [12000/12000 00:12<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 5_000 draw iterations (2_000 + 10_000 draws total) took 18 seconds.

# %% [markdown]
# The posteriors are sort-of biased towards the prior means, but they work pretty well still!

# %%
# %matplotlib notebook
vary_sigma()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <ipython-input-80-8cf759d35e74>:15: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(iters, chains=num_chain)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [theta]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='12000' class='' max='12000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [12000/12000 00:12<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 5_000 draw iterations (2_000 + 10_000 draws total) took 18 seconds.
# <ipython-input-80-8cf759d35e74>:15: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(iters, chains=num_chain)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [theta]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='12000' class='' max='12000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [12000/12000 00:06<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 5_000 draw iterations (2_000 + 10_000 draws total) took 13 seconds.
# <ipython-input-80-8cf759d35e74>:15: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(iters, chains=num_chain)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [theta]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='12000' class='' max='12000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [12000/12000 00:06<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 5_000 draw iterations (2_000 + 10_000 draws total) took 11 seconds.
# <ipython-input-80-8cf759d35e74>:15: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(iters, chains=num_chain)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [theta]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='12000' class='' max='12000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [12000/12000 00:05<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 5_000 draw iterations (2_000 + 10_000 draws total) took 11 seconds.

# %% [markdown]
# The posteriors are sort-of biased towards the prior mean for narrower priors, but they work pretty well still!

# %% [markdown]
# # Part 2

# %% [markdown]
# As before, the random variable we deal with is $\theta_k$, which is distributed uniformly. We can write: $$\tan(\theta_k) = \frac{x_k - \alpha}{\beta}$$
# $$x_k = \alpha + \beta\tan(\theta_k)$$

# %% [markdown]
# Now, as due to normalization $\int p(\theta)d\theta = 1 = \int p(x) dx$. Doing a substitution, $p(\theta) = p(x) \frac{dx}{d\theta}$, or:
# $$p(x) = p(\theta) \frac{d\theta}{dx} \propto \frac{1}{\beta \sec^2(\theta_k)} = \frac{1}{\beta + \beta \tan^2(\theta_k)} = \frac{1}{\beta + (x-\alpha)^2/ \beta} = \frac{\beta}{\beta^2 + (x-\alpha)^2}$$
# We will use this $p(x)$ to get our likelihood function.

# %%
def simulateX_k(alpha_true, beta_true, n):
    theta = np.random.random(n) * np.pi - (np.pi / 2)
    return alpha_true + beta_true * np.tan(theta)

# %%
alpha_true = 1
beta_true = 1 
n = 512

trials = simulateX_k(alpha_true, beta_true, n)

# %%
def vary_number_of_chains_lighthouse(num_chains = [1, 2, 4, 8]):
    iters = 1000
    for i, num_chain in enumerate(num_chains):
        pl.figure(i)
        with pm.Model() as model:
            # define uniform prior
            alpha = pm.Uniform('alpha', lower=-5, upper=5)
            beta = pm.Uniform('beta', lower=0, upper=5)

            # define the likelihood
            likelihood = pm.Cauchy('likelihood', alpha=alpha, beta=beta, observed=trials)

            # get the samples
            trace = pm.sample(iters, chains=num_chain)
            
            heatmap, xedges, yedges = np.histogram2d(trace["alpha"], trace["beta"], bins=50)
            extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]
            pl.clf()
            pl.imshow(heatmap.T, extent=extent, origin='lower')
            pl.title(r'$\alpha-\beta$ posterior heatmap for {} chain(s)'.format(num_chain))
            pl.ylabel(r'$\alpha$')
            pl.xlabel(r'$\beta$')
            pl.show()

# %%
# %matplotlib notebook
vary_number_of_chains_lighthouse()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <ipython-input-115-01b0f22f1511>:14: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(iters, chains=num_chain)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [beta, alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 00:01<00:00 Sampling chain 0, 0 divergences]
#     </div>
# Sampling 1 chain for 1_000 tune and 1_000 draw iterations (1_000 + 1_000 draws total) took 2 seconds.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# <img src="data:image/png;base64,..." width="640">
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [beta, alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 00:06<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 1_000 draw iterations (2_000 + 2_000 draws total) took 13 seconds.
# <img src="data:image/png;base64,..." width="640">
# <ipython-input-115-01b0f22f1511>:14: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(iters, chains=num_chain)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 2 jobs)
# NUTS: [beta, alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:09<00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 20 seconds.
# <img src="data:image/png;base64,..." width="640">
# <ipython-input-115-01b0f22f1511>:14: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(iters, chains=num_chain)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (8 chains in 2 jobs)
# NUTS: [beta, alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='16000' class='' max='16000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [16000/16000 00:17<00:00 Sampling 8 chains, 0 divergences]
#     </div>
# Sampling 8 chains for 1_000 tune and 1_000 draw iterations (8_000 + 8_000 draws total) took 40 seconds.

# %%
def vary_number_of_iterations_lighthouse(num_iters = [1000, 2000, 4000, 8000]):
    num_chain = 2
    for i, iters in enumerate(num_iters):
        pl.figure(i)
        with pm.Model() as model:
            # define uniform prior
            alpha = pm.Uniform('alpha', lower=-5, upper=5)
            beta = pm.Uniform('beta', lower=0, upper=5)

            # define the likelihood
            likelihood = pm.Cauchy('likelihood', alpha=alpha, beta=beta, observed=trials)

            # get the samples
            trace = pm.sample(iters, chains=num_chain)
            
            heatmap, xedges, yedges = np.histogram2d(trace["alpha"], trace["beta"], bins=50)
            extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]
            pl.clf()
            pl.imshow(heatmap.T, extent=extent, origin='lower')
            pl.title(r'$\alpha-\beta$ posterior heatmap for {} iterations'.format(iters))
            pl.ylabel(r'$\alpha$')
            pl.xlabel(r'$\beta$')
            pl.show()

# %%
# %matplotlib notebook
vary_number_of_iterations_lighthouse()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <ipython-input-131-308730ac486f>:14: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(iters, chains=num_chain)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [beta, alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 00:05<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 1_000 draw iterations (2_000 + 2_000 draws total) took 10 seconds.
# <img src="data:image/png;base64,..." width="640">
# <ipython-input-131-308730ac486f>:14: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(iters, chains=num_chain)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [beta, alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='6000' class='' max='6000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [6000/6000 00:05<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 2_000 draw iterations (2_000 + 4_000 draws total) took 11 seconds.
# <img src="data:image/png;base64,..." width="640">
# <ipython-input-131-308730ac486f>:14: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(iters, chains=num_chain)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [beta, alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='10000' class='' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [10000/10000 00:09<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 4_000 draw iterations (2_000 + 8_000 draws total) took 15 seconds.
# <img src="data:image/png;base64,..." width="640">
# <ipython-input-131-308730ac486f>:14: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(iters, chains=num_chain)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [beta, alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='18000' class='' max='18000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [18000/18000 00:18<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 8_000 draw iterations (2_000 + 16_000 draws total) took 24 seconds.

# %% [markdown]
# Again, as before, the heat map peak becomes more and more significant when we incease the effective number of samples

# %%
def get_most_probable_xy(num_chains = [1, 2, 4], num_iters = [100, 500, 1000, 2000]):
    Xs = {}
    Ys = {}
    for num_chain in num_chains:
        max_xs = []
        max_ys = []
        for i, iters in enumerate(num_iters):
            with pm.Model() as model:
                # define uniform prior
                alpha = pm.Uniform('alpha', lower=-5, upper=5)
                beta = pm.Uniform('beta', lower=0, upper=5)

                # define the likelihood
                likelihood = pm.Cauchy('likelihood', alpha=alpha, beta=beta, observed=trials)

                # get the samples
                trace = pm.sample(iters, chains=num_chain)
                
                cx, bx = np.histogram(trace["alpha"], bins = 100)
                cy, by = np.histogram(trace["beta"], bins = 100)
                
                max_xs += [bx[np.argmax(cx)]]
                max_ys += [by[np.argmax(cy)]]
                
        Xs[num_chain] = max_xs
        Ys[num_chain] = max_ys
    return Xs, Ys

# %%
Xs, Ys = get_most_probable_xy()
# Out:
# <ipython-input-158-3e75a4df5195>:17: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(iters, chains=num_chain)
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [beta, alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1100' class='' max='1100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1100/1100 00:00<00:00 Sampling chain 0, 0 divergences]
#     </div>
# Sampling 1 chain for 1_000 tune and 100 draw iterations (1_000 + 100 draws total) took 1 seconds.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [beta, alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1500' class='' max='1500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1500/1500 00:01<00:00 Sampling chain 0, 0 divergences]
#     </div>
# Sampling 1 chain for 1_000 tune and 500 draw iterations (1_000 + 500 draws total) took 1 seconds.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [beta, alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 00:02<00:00 Sampling chain 0, 0 divergences]
#     </div>
# Sampling 1 chain for 1_000 tune and 1_000 draw iterations (1_000 + 1_000 draws total) took 2 seconds.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [beta, alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3000' class='' max='3000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3000/3000 00:03<00:00 Sampling chain 0, 0 divergences]
#     </div>
# Sampling 1 chain for 1_000 tune and 2_000 draw iterations (1_000 + 2_000 draws total) took 3 seconds.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [beta, alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2200' class='' max='2200' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2200/2200 00:03<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 100 draw iterations (2_000 + 200 draws total) took 8 seconds.
# <ipython-input-158-3e75a4df5195>:17: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(iters, chains=num_chain)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [beta, alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3000' class='' max='3000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3000/3000 00:03<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 500 draw iterations (2_000 + 1_000 draws total) took 9 seconds.
# <ipython-input-158-3e75a4df5195>:17: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(iters, chains=num_chain)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [beta, alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 00:05<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 1_000 draw iterations (2_000 + 2_000 draws total) took 10 seconds.
# <ipython-input-158-3e75a4df5195>:17: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(iters, chains=num_chain)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [beta, alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='6000' class='' max='6000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [6000/6000 00:06<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 2_000 draw iterations (2_000 + 4_000 draws total) took 12 seconds.
# <ipython-input-158-3e75a4df5195>:17: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(iters, chains=num_chain)
# Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 2 jobs)
# NUTS: [beta, alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4400' class='' max='4400' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4400/4400 00:06<00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 100 draw iterations (4_000 + 400 draws total) took 17 seconds.
# The acceptance probability does not match the target. It is 0.8819922637384807, but should be close to 0.8. Try to increase the number of tuning steps.
# <ipython-input-158-3e75a4df5195>:17: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(iters, chains=num_chain)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 2 jobs)
# NUTS: [beta, alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='6000' class='' max='6000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [6000/6000 00:06<00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 500 draw iterations (4_000 + 2_000 draws total) took 17 seconds.
# <ipython-input-158-3e75a4df5195>:17: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(iters, chains=num_chain)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 2 jobs)
# NUTS: [beta, alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:09<00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 19 seconds.
# <ipython-input-158-3e75a4df5195>:17: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(iters, chains=num_chain)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 2 jobs)
# NUTS: [beta, alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='12000' class='' max='12000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [12000/12000 00:12<00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 2_000 draw iterations (4_000 + 8_000 draws total) took 23 seconds.

# %%
num_iters = [100, 500, 1000, 2000]
for i, num_chain in enumerate(Xs.keys()):    
    max_xs = Xs[num_chain]
    max_ys = Ys[num_chain]
    pl.figure(1)
    pl.plot(num_iters, max_xs, ".-", label = f"{num_chain} chains")
    pl.figure(2)
    pl.plot(num_iters, max_ys, ".-", label = f"{num_chain} chains")

pl.figure(1)            
pl.title(r'most probable $\alpha$ in posterior')
pl.ylabel(r'$\alpha$')
pl.xlabel(r'number of iterations')
pl.axhline(y = alpha_true, color = "black")
pl.legend()
pl.show()
pl.figure(2)
pl.title(r'most probable $\beta$ in posterior')
pl.ylabel(r'$\beta$')
pl.xlabel(r'number of iterations')
pl.axhline(y = beta_true, color = "black")
pl.legend()
pl.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Increasing iteration number seems to have a much larger effect than increasing the number of chains.

# %% [markdown]
# # Adding an interloper

# %%
alpha_true = 3
beta_true = 3
n = 512

inter_alpha = 1
inter_beta = 1

trials = simulateX_k(alpha_true, beta_true, n)

# %%
with pm.Model() as model:
    # define uniform prior
    alpha = pm.Uniform('alpha', lower=-5, upper=5)
    beta = pm.Uniform('beta', lower=0, upper=5)

    # define the likelihood
    likelihood = pm.Cauchy('likelihood', alpha=alpha, beta=beta, observed=trials)

    # get the samples
    trace = pm.sample(5000, chains=4)

    heatmap, xedges, yedges = np.histogram2d(trace["alpha"], trace["beta"], bins=50)
    extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]
    pl.clf()
    pl.imshow(heatmap.T, extent=extent, origin='lower')
    pl.title(r'$\alpha-\beta$ without an interloper'.format(num_chain))
    pl.ylabel(r'$\alpha$')
    pl.xlabel(r'$\beta$')
    pl.show()
# Out:
# <ipython-input-193-66d537a8289c>:10: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(5000, chains=4)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 2 jobs)
# NUTS: [beta, alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='24000' class='' max='24000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [24000/24000 00:21<00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 5_000 draw iterations (4_000 + 20_000 draws total) took 32 seconds.
# <img src="data:image/png;base64,..." width="640">

# %%
trials += simulateX_k(inter_alpha, inter_beta, n)
np.random.shuffle(trials)

with pm.Model() as model:
    # define uniform prior
    alpha = pm.Uniform('alpha', lower=-5, upper=5)
    beta = pm.Uniform('beta', lower=0, upper=5)

    # define the likelihood
    likelihood = pm.Cauchy('likelihood', alpha=alpha, beta=beta, observed=trials)

    # get the samples
    trace = pm.sample(5000, chains=4)

    heatmap, xedges, yedges = np.histogram2d(trace["alpha"], trace["beta"], bins=50)
    extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]
    pl.clf()
    pl.imshow(heatmap.T, extent=extent, origin='lower')
    pl.title(r'$\alpha-\beta$ with an interloper'.format(num_chain))
    pl.ylabel(r'$\alpha$')
    pl.xlabel(r'$\beta$')
    pl.show()
# Out:
# <ipython-input-194-48aba197e61d>:13: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(5000, chains=4)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 2 jobs)
# NUTS: [beta, alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='24000' class='' max='24000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [24000/24000 00:23<00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 5_000 draw iterations (4_000 + 20_000 draws total) took 33 seconds.
# The acceptance probability does not match the target. It is 0.898001669967243, but should be close to 0.8. Try to increase the number of tuning steps.
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# MCMC is surprising not able to detect two sources of the flashes, instead it simply predicts a higher $\alpha$ and higher $\beta$. This might be because that sum of two Cauchy random variables is also a Cauchy distribution (as the trials are basically values from two independent Cauchy distributions). Notably, for if $X$ is sampled from Cauchy($\alpha_1$, $\beta_2$) and $Y$ from Cauchy($\alpha_2$, $\beta_2$), their sum $X+Y$ is from Cauchy($\alpha_1 + \alpha_2$, $\beta_1 + \beta_2$). This is the kind of behaviour we are seeing in this heatmap, as $\alpha_{t} + \alpha_{i} = 3 + 1 = 4 = \beta_{t} + \beta_{i}$, and this heat map has a peak close to $(4,4)$.
#
# It might be important to note that if the interloper position changes with time, we will see this peak move (if the speed is low enough to get separate integration times for the trails). In that sense, we can extract both lighthouse and interloper position as a function of time.
